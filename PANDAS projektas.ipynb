# %%
import pandas as pd

# %%
na_vals = ["NA", "Missing"]
df = pd.read_csv("C:/Users/Vartotojas/Desktop/pandas/2019/survey_results_public.csv", index_col='Respondent')
schema_df = pd.read_csv("C:/Users/Vartotojas/Desktop/pandas/2019/survey_results_schema.csv", index_col="Column")

# %%
pd.set_option("display.max_columns", 85)
pd.set_option("display.max_rows", 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df["Hobbyist"].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[1:200, ["Country"]].value_counts()
# Out:
# Country
# United States             46
# India                     20
# Germany                   11
# United Kingdom            11
# Canada                     9
# Australia                  6
# Russian Federation         5
# Netherlands                5
# Spain                      5
# Italy                      4
# New Zealand                4
# South Africa               4
# Argentina                  4
# Poland                     4
# Austria                    4
# France                     3
# Brazil                     3
# Sri Lanka                  2
# Pakistan                   2
# Bangladesh                 2
# Bosnia and Herzegovina     2
# Malaysia                   2
# Turkey                     2
# Czech Republic             2
# Ukraine                    2
# Sweden                     2
# Switzerland                2
# Greece                     2
# Croatia                    2
# Estonia                    2
# China                      2
# ...

# %%
df.loc[1:20, "Hobbyist": "Country"]
# Out:
#            Hobbyist                                        OpenSourcer  \
# Respondent
# 1               Yes                                              Never
# 2                No                            Less than once per year
# 3               Yes                                              Never
# 4                No                                              Never
# 5               Yes                         Once a month or more often
# 6               Yes                                              Never
# 7                No                                              Never
# 8               Yes                            Less than once per year
# 9               Yes                         Once a month or more often
# 10              Yes                         Once a month or more often
# 11              Yes                         Once a month or more often
# 12               No                                              Never
# ...

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema_df.loc["MgrIdiot", "QuestionText"]
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index(ascending=True, inplace=True)

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
high_salary = (df["ConvertedComp"] > 70000)

# %%
df.loc[high_salary, ["Country", "LanguageWorkedWith", "ConvertedComp"]]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = ["United States", "India", "United Kingdom", "Germany"]
filt = df["Country"].isin(countries)

# %%
df.loc[filt]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 4                   I am a developer by profession       No
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 13                  I am a developer by profession      Yes
# ...                                            ...      ...
# 84539                                          NaN      Yes
# 85642                                          NaN       No
# 85961                                          NaN      Yes
# 86012                                          NaN      Yes
# 88282                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 4                                                       Never
# ...

# %%
filt = df["LanguageWorkedWith"].str.contains("Python", na=False)

# %%
df.loc[filt]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# 4                   I am a developer by profession       No
# 5                   I am a developer by profession      Yes
# 8                      I code primarily as a hobby      Yes
# ...                                            ...      ...
# 84539                                          NaN      Yes
# 85738                                          NaN      Yes
# 86566                                          NaN      Yes
# 87739                                          NaN      Yes
# 88212                                          NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# ...

# %%
df.loc[filt, "LanguageWorkedWith"]
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.rename(columns={"ConvertedComp": "SalaryUSD"}, inplace=True)

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq', 'SalaryUSD',
#        'WorkWeekHrs', 'WorkPlan', 'WorkChallenge', 'WorkRemote', 'WorkLoc',
#        'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests', 'PurchaseHow',
#        'PurchaseWhat', 'LanguageWorkedWith', 'LanguageDesireNextYear',
#        'DatabaseWorkedWith', 'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df["Hobbyist"]
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df["Hobbyist"].map({"Yes": True, "No": False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df.sort_values(by=["Country", "SalaryUSD"], ascending=[True, False], inplace = True)

# %%
df[["Country", "SalaryUSD"]].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0
# 22450       Afghanistan     7980.0
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 8149        Afghanistan     1596.0
# 29736       Afghanistan     1116.0
# 28638       Afghanistan        0.0
# 722         Afghanistan        0.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN
# 63019       Afghanistan        NaN
# 6417        Afghanistan        NaN
# 40000       Afghanistan        NaN
# 88731       Afghanistan        NaN
# 62525       Afghanistan        NaN
# 49702       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 60946       Afghanistan        NaN
# 86362       Afghanistan        NaN
# 88582       Afghanistan        NaN
# ...

# %%
df[["Country", "SalaryUSD"]].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 39258       Afghanistan    19152.0
# 63129       Afghanistan  1000000.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN
# 63019       Afghanistan        NaN
# 6417        Afghanistan        NaN
# 40000       Afghanistan        NaN
# 88731       Afghanistan        NaN
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 62525       Afghanistan        NaN
# 49702       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 60946       Afghanistan        NaN
# 86362       Afghanistan        NaN
# 88582       Afghanistan        NaN
# 28638       Afghanistan        0.0
# 722         Afghanistan        0.0
# 26340       Afghanistan        NaN
# 86932       Afghanistan        NaN
# 85825       Afghanistan        NaN
# 7085        Afghanistan    14364.0
# 7353        Afghanistan        NaN
# 87091       Afghanistan        NaN
# ...

# %%
df["SalaryUSD"].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10, "SalaryUSD")
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      Yes
# 87896                          I am a developer by profession      Yes
# 22013                          I am a developer by profession      Yes
# 28243                          I am a developer by profession      Yes
# 72732       I am not primarily a developer, but I write co...       No
# 78151                          I am a developer by profession      Yes
# 80200                          I am a developer by profession      Yes
# 52132                          I am a developer by profession      Yes
# 75561                          I am a developer by profession      Yes
# 32250                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
df.nsmallest(10, "SalaryUSD")
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 28638                          I am a developer by profession      Yes
# 722                            I am a developer by profession       No
# 13825                          I am a developer by profession      Yes
# 40913                          I am a developer by profession      Yes
# 30630                          I am a developer by profession      Yes
# 69049                          I am a developer by profession       No
# 19340       I am not primarily a developer, but I write co...      Yes
# 16214       I am not primarily a developer, but I write co...      Yes
# 29355                          I am a developer by profession      Yes
# 1685                           I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 28638       Less than once a month but more than once per ...
# ...

# %%
df.sort_index()
df["SalaryUSD"].sort_index().head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3       8820.0
# 4      61000.0
# 5          NaN
# 6     366420.0
# 7          NaN
# 8          NaN
# 9      95179.0
# 10     13293.0
# 11         NaN
# 12         NaN
# 13     90000.0
# 14     57060.0
# 15         NaN
# Name: SalaryUSD, dtype: float64

# %%
df["SalaryUSD"].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# C:\Users\Vartotojas\AppData\Local\Temp\ipykernel_16412\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# CompTotal      62000.0
# SalaryUSD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %%
df["SalaryUSD"].count()
# Out:
# 55823

# %%
df["Hobbyist"].sort_index()
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88879    Yes
# 88880    Yes
# 88881    Yes
# 88882    Yes
# 88883    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df["Hobbyist"].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df["SocialMedia"].sort_index()
# Out:
# Respondent
# 1          Twitter
# 2        Instagram
# 3           Reddit
# 4           Reddit
# 5         Facebook
#            ...
# 88879      YouTube
# 88880          NaN
# 88881          NaN
# 88882    Instagram
# 88883       Reddit
# Name: SocialMedia, Length: 88883, dtype: object

# %%
schema_df.loc["SocialMedia"]
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
schema_df.head(3)
# Out:
#                                                  QuestionText
# Column
# Age         What is your age (in years)? If you prefer not...
# Age1stCode  At what age did you write your first line of c...
# BetterLife  Do you think people born today will have a bet...

# %%
df["SocialMedia"].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
df["Country"].value_counts()
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Brunei Darussalam                       1
# Chad                                    1
# Dominica                                1
# Saint Vincent and the Grenadines        1
# Tonga                                   1
# Name: Country, Length: 179, dtype: int64

# %%
country_grp = df.groupby(["Country"])

# %%
country_grp.get_group("United States").sort_index()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 4                              I am a developer by profession       No
# 13                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# 23                             I am a developer by profession      Yes
# 26                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88875       I used to be a developer by profession, but no...      Yes
# 88876                          I am a developer by profession      Yes
# 88877                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
# 88880       I am not primarily a developer, but I write co...      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
filt = df["Country"] == "United States"
df.loc[filt]["SocialMedia"].value_counts()
# Out:
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: SocialMedia, dtype: int64

# %%
country_grp["SocialMedia"].value_counts().head(20)
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#              LinkedIn                     1
#              Twitter                      1
# Albania      WhatsApp                    18
#              Facebook                    16
#              Instagram                   13
#              YouTube                     10
#              Twitter                      8
#              LinkedIn                     7
#              Reddit                       6
#              I don't use social media     4
#              Snapchat                     1
#              WeChat 微信                    1
# Algeria      YouTube                     42
#              Facebook                    41
#              Twitter                     14
# Name: SocialMedia, dtype: int64

# %%
country_grp["SocialMedia"].value_counts(normalize=True).loc[["India","China"]]
# Out:
# Country  SocialMedia
# India    WhatsApp                    0.342379
#          YouTube                     0.208405
#          LinkedIn                    0.109355
#          Facebook                    0.096301
#          Instagram                   0.094126
#          Twitter                     0.062063
#          Reddit                      0.054162
#          I don't use social media    0.028627
#          Snapchat                    0.002634
#          Hello                       0.000573
#          WeChat 微信                   0.000573
#          VK ВКонта́кте               0.000458
#          Youku Tudou 优酷              0.000229
#          Weibo 新浪微博                  0.000115
# China    WeChat 微信                   0.670549
#          YouTube                     0.088186
#          Weibo 新浪微博                  0.069884
#          I don't use social media    0.044925
#          Twitter                     0.044925
#          Reddit                      0.019967
# ...

# %%
country_grp["SalaryUSD"].describe().sort_values(by = "50%", ascending = False).head(10)
# Out:
#                                     count           mean            std  \
# Country
# Liechtenstein                         1.0  811188.000000            NaN
# San Marino                            2.0  301788.000000  389847.767458
# Timor-Leste                           1.0  229500.000000            NaN
# Andorra                               2.0  160931.000000   15458.768450
# Democratic Republic of the Congo      1.0  110484.000000            NaN
# United States                     14981.0  249546.254589  452103.496531
# Switzerland                         672.0  172675.602679  260551.516069
# Israel                              579.0   94944.376511   81949.011168
# Ireland                             343.0  250342.239067  327004.152729
# Denmark                             420.0  113769.554762  157030.594460
#
#                                        min       25%       50%        75%  \
# Country
# Liechtenstein                     811188.0  811188.0  811188.0  811188.00
# ...

# %%
country_grp["SalaryUSD"].median().loc["Germany"]
# Out:
# 63016.0

# %%
country_grp["SalaryUSD"].agg(["median", "mean"])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
country_grp["SalaryUSD"].agg(["median", "mean"]).loc["Canada"]
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt = df["Country"] == "India"
df.loc[filt]["LanguageWorkedWith"].str.contains("Python").sum()
# Out:
# 3105

# %%
country_grp["LanguageWorkedWith"].apply(lambda x: x.str.contains("Python").sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_grp["LanguageWorkedWith"].apply(lambda x: x.str.contains("Python").value_counts(normalize=True))
# Out:
# Country
# Afghanistan  False    0.794872
#              True     0.205128
# Albania      False    0.722892
#              True     0.277108
# Algeria      False    0.682540
#                         ...
# Yemen        True     0.176471
# Zambia       False    0.666667
#              True     0.333333
# Zimbabwe     False    0.641026
#              True     0.358974
# Name: LanguageWorkedWith, Length: 335, dtype: float64

# %%
country_resp = df["Country"].value_counts()
country_resp
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Brunei Darussalam                       1
# Chad                                    1
# Dominica                                1
# Saint Vincent and the Grenadines        1
# Tonga                                   1
# Name: Country, Length: 179, dtype: int64

# %%
country_python = country_grp["LanguageWorkedWith"].apply(lambda x: x.str.contains("Python").sum())

# %%
python_df = pd.concat([country_resp, country_python], axis = "columns", sort = False)
python_df
# Out:
#                                   Country  LanguageWorkedWith
# United States                       20949               10083
# India                                9061                3105
# Germany                              5866                2451
# United Kingdom                       5737                2384
# Canada                               3395                1558
# ...                                   ...                 ...
# Brunei Darussalam                       1                   0
# Chad                                    1                   0
# Dominica                                1                   1
# Saint Vincent and the Grenadines        1                   0
# Tonga                                   1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={"Country": "Country_respondents", "knows_python": "Num_knows_python"})
# Out:
#                                   Country_respondents  Num_knows_python  \
# United States                                   20949             10083
# India                                            9061              3105
# Germany                                          5866              2451
# United Kingdom                                   5737              2384
# Canada                                           3395              1558
# ...                                               ...               ...
# Brunei Darussalam                                   1                 0
# Chad                                                1                 0
# Dominica                                            1                 1
# Saint Vincent and the Grenadines                    1                 0
# Tonga                                               1                 0
#
#                                   PctKnowPython
# United States                         48.131176
# ...

# %%
python_df.drop(columns = ["PctKnowPython"], inplace=True)

# %%
python_df["Pct_Python"] = (python_df["knows_python"] / python_df["Country_respondents"]) * 100

# %%
python_df
# Out:
#                                   Country_respondents  knows_python  \
# United States                                   20949         10083
# India                                            9061          3105
# Germany                                          5866          2451
# United Kingdom                                   5737          2384
# Canada                                           3395          1558
# ...                                               ...           ...
# Brunei Darussalam                                   1             0
# Chad                                                1             0
# Dominica                                            1             1
# Saint Vincent and the Grenadines                    1             0
# Tonga                                               1             0
#
#                                   Pct_Python
# United States                      48.131176
# India                              34.267741
# ...

# %%
python_df.sort_values(by = "Pct_Python", ascending = False, inplace = True)

# %%
python_df
# Out:
#                        Country_respondents  knows_python  Pct_Python
# Dominica                                 1             1  100.000000
# Sao Tome and Principe                    1             1  100.000000
# Timor-Leste                              1             1  100.000000
# Niger                                    1             1  100.000000
# Turkmenistan                             7             6   85.714286
# ...                                    ...           ...         ...
# Burkina Faso                             4             0    0.000000
# Gabon                                    2             0    0.000000
# Cape Verde                               3             0    0.000000
# Malawi                                   2             0    0.000000
# Tonga                                    1             0    0.000000
#
# [179 rows x 3 columns]

# %%
python_df.loc["Japan"]
# Out:
# Country_respondents    391.000000
# knows_python           182.000000
# Pct_Python              46.547315
# Name: Japan, dtype: float64

# %%
df["YearsCode"].sort_index().head(10)
# Out:
# Respondent
# 1       4
# 2     NaN
# 3       3
# 4       3
# 5      16
# 6      13
# 7       6
# 8       8
# 9      12
# 10     12
# Name: YearsCode, dtype: object

# %%
df["YearsCode"].unique()
# Out:
# array(['17', '14', '7', '11', '28', '8', '5', '3', '4', '10', '24', '15',
#        '9', '20', '12', '25', '6', 'More than 50 years', '26', '36', '35',
#        '32', 'Less than 1 year', '43', '2', '16', '1', '40', '30', '27',
#        '39', '23', '34', '37', '22', '29', '18', '13', '50', nan, '19',
#        '33', '42', '31', '21', '38', '44', '45', '48', '41', '47', '46',
#        '49'], dtype=object)

# %%
df["YearsCode"].replace('More than 50 years', 51, inplace=True)
df["YearsCode"].replace('Less than 1 year', 0, inplace=True)
df["YearsCode"] = df["YearsCode"].astype(float)

# %%
df["YearsCode"].mean()
# Out:
# 11.662114216834588

# %%
df["YearsCode"].median()
# Out:
# 9.0

# %%
df["YearsCode"].describe()
# Out:
# count    87938.000000
# mean        11.662114
# std          9.152772
# min          0.000000
# 25%          5.000000
# 50%          9.000000
# 75%         15.000000
# max         51.000000
# Name: YearsCode, dtype: float64

# %%
filt = (df["Country"]) == "India"
india_df = df.loc[filt]
india_df.sort_index().head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
india_df.to_csv("C:/Users/Vartotojas/Desktop/pandas/modified_India.csv")

# %%
india_df.to_csv("C:/Users/Vartotojas/Desktop/pandas/modified_India.tsv", sep="\t")

# %%
india_df.to_excel("C:/Users/Vartotojas/Desktop/pandas/modified_India2.xlsx")

# %%
test = pd.read_excel("C:/Users/Vartotojas/Desktop/pandas/modified_India2.xlsx", index_col = "Respondent")

# %%
test.sort_index().head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
india_df.to_json("C:/Users/Vartotojas/Desktop/pandas/modified_India3.xlsx")

# %%
india_df.to_json("C:/Users/Vartotojas/Desktop/pandas/modified_India4.xlsx", orient = "records", lines =True)

# %%
test2 = pd.read_json("C:/Users/Vartotojas/Desktop/pandas/modified_India4.xlsx", orient = "records", lines =True)

# %%
test2.sort_index().head()
# Out:
#                        MainBranch Hobbyist  \
# 0  I am a developer by profession      Yes
# 1  I am a developer by profession      Yes
# 2  I am a developer by profession      Yes
# 3  I am a developer by profession      Yes
# 4  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0  Less than once a month but more than once per ...
# 1                            Less than once per year
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4                         Once a month or more often
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 3  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %%
posts_df = pd.read_json('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Flask_Blog/snippets/posts.json')

# %%
posts_df.head()
# Out:
#                           title  \
# 0               My Updated Post
# 1                 A Second Post
# 2  Top 5 Programming Lanaguages
# 3  Sublime Text Tips and Tricks
# 4              Best Python IDEs
#
#                                              content  user_id
# 0    My first updated post!\r\n\r\nThis is exciting!        1
# 1            This is a post from a different user...        2
# 2  Te melius apeirian postulant cum, labitur admo...        1
# 3  Ea vix dico modus voluptatibus, mel iudico sua...        1
# 4  Elit contentiones nam no, sea ut consul adipis...        1
